# %%
# Install libraries yang diperlukan
# !pip install pandas numpy scikit-learn nltk gensim wordcloud matplotlib seaborn pyLDAvis
# Out:
# ...
#   Using cached gensim-4.4.0.tar.gz (23.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached wordcloud-1.9.5-cp314-cp314-win_amd64.whl.metadata (3.5 kB)
# ...
#   Using cached matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached pyLDAvis-3.4.1-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# ...
#   Using cached pillow-12.0.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...

# %%
import pandas as pd
import numpy as np
import re
import pickle

# NLP libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Topic Modeling
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from gensim import corpora
from gensim.models import LdaModel

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# Download NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 15
#      13 from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
#      14 from sklearn.decomposition import LatentDirichletAllocation
# ---> 15 from gensim import corpora
#      16 from gensim.models import LdaModel
#      18 # Visualization
#
# ModuleNotFoundError: No module named 'gensim'

# %% [markdown]
# ## 1. Load Data
# Upload file CSV Anda ke Colab menggunakan file upload atau dari Google Drive

# %%
# Baca file CSV yang sudah diupload ke Colab
# Upload file CSV Anda ke file panel Colab (klik ikon folder di kiri > upload)
# Kemudian sesuaikan nama file di bawah ini

# Ganti 'nama_file.csv' dengan nama file CSV Anda
# df = pd.read_csv('itb_news.csv')  # Sesuaikan nama file

# ATAU jika file ada di folder tertentu:
# df = pd.read_csv('folder/nama_file.csv')

# ATAU jika file di Google Drive:
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/itb_news.csv')

print(f"\nDataset shape: {df.shape}")
print(f"Column names: {df.columns.tolist()}")

# Pastikan ada kolom yang berisi teks berita
# Jika nama kolom berbeda dari 'text', sesuaikan di bawah ini:
# Contoh: jika kolom berita bernama 'content' atau 'artikel':
# df = df.rename(columns={'content': 'text'})

# Atau jika ingin menggabungkan beberapa kolom:
# df['text'] = df['judul'].fillna('') + ' ' + df['konten'].fillna('')

print(f"\nTotal documents: {len(df)}")
df.head()

# %% [markdown]
# ## 2. Text Preprocessing

# %%
class TextPreprocessor:
    def __init__(self, language='english'):
        self.stop_words = set(stopwords.words(language))
        self.lemmatizer = WordNetLemmatizer()

    def clean_text(self, text):
        """Membersihkan teks dari karakter khusus"""
        text = str(text).lower()
        text = re.sub(r'[^a-zA-Z\s]', '', text)
        text = re.sub(r'\s+', ' ', text).strip()
        return text

    def tokenize_and_lemmatize(self, text):
        """Tokenisasi dan lemmatisasi"""
        tokens = word_tokenize(text)
        tokens = [self.lemmatizer.lemmatize(word) for word in tokens
                 if word not in self.stop_words and len(word) > 2]
        return tokens

    def preprocess(self, text):
        """Pipeline preprocessing lengkap"""
        cleaned = self.clean_text(text)
        tokens = self.tokenize_and_lemmatize(cleaned)
        return ' '.join(tokens)

# Preprocessing
preprocessor = TextPreprocessor()
df['cleaned_text'] = df['content'].apply(preprocessor.preprocess)
df['tokens'] = df['cleaned_text'].apply(lambda x: x.split())

print("\nContoh hasil preprocessing:")
print(f"Original: {df['content'][0]}")
print(f"Cleaned: {df['cleaned_text'][0]}")

# %% [markdown]
# ## 3. Topic Modeling dengan Scikit-learn LDA

# %%
# Vectorization
n_topics = 3  # Sesuaikan dengan kebutuhan
vectorizer = CountVectorizer(max_features=1000, min_df=2, max_df=0.8)
doc_term_matrix = vectorizer.fit_transform(df['cleaned_text'])

print(f"Document-Term Matrix shape: {doc_term_matrix.shape}")

# Train LDA model
lda_model = LatentDirichletAllocation(
    n_components=n_topics,
    random_state=42,
    max_iter=20,
    learning_method='online'
)

lda_output = lda_model.fit_transform(doc_term_matrix)

print(f"\nModel trained with {n_topics} topics")
print(f"Log Likelihood: {lda_model.score(doc_term_matrix)}")
print(f"Perplexity: {lda_model.perplexity(doc_term_matrix)}")

# %%
# Display top words per topic
def display_topics(model, feature_names, n_top_words=10):
    topics = {}
    for topic_idx, topic in enumerate(model.components_):
        top_indices = topic.argsort()[-n_top_words:][::-1]
        top_words = [feature_names[i] for i in top_indices]
        topics[f"Topic {topic_idx + 1}"] = top_words
        print(f"\nTopic {topic_idx + 1}:")
        print(", ".join(top_words))
    return topics

feature_names = vectorizer.get_feature_names_out()
topics_dict = display_topics(lda_model, feature_names, n_top_words=10)

# %% [markdown]
# ## 4. Topic Modeling dengan Gensim (Alternatif)

# %%
# Membuat dictionary dan corpus untuk Gensim
dictionary = corpora.Dictionary(df['tokens'])
corpus = [dictionary.doc2bow(text) for text in df['tokens']]

# Train Gensim LDA model
gensim_lda = LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=n_topics,
    random_state=42,
    passes=10,
    alpha='auto',
    per_word_topics=True
)

# Display topics
print("\nGensim LDA Topics:")
for idx, topic in gensim_lda.print_topics(-1):
    print(f"Topic {idx + 1}: {topic}")

# %% [markdown]
# ## 5. Visualisasi

# %%
# Document-Topic Distribution
df['dominant_topic'] = lda_output.argmax(axis=1)

plt.figure(figsize=(10, 6))
topic_counts = df['dominant_topic'].value_counts().sort_index()
sns.barplot(x=topic_counts.index, y=topic_counts.values)
plt.title('Distribution of Documents Across Topics')
plt.xlabel('Topic')
plt.ylabel('Number of Documents')
plt.xticks(range(n_topics), [f'Topic {i+1}' for i in range(n_topics)])
plt.tight_layout()
plt.savefig('topic_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Word Cloud untuk setiap topic
fig, axes = plt.subplots(1, n_topics, figsize=(15, 5))
if n_topics == 1:
    axes = [axes]

for topic_idx, topic in enumerate(lda_model.components_):
    top_indices = topic.argsort()[-20:][::-1]
    top_words = {feature_names[i]: topic[i] for i in top_indices}

    wordcloud = WordCloud(
        width=400,
        height=300,
        background_color='white'
    ).generate_from_frequencies(top_words)

    axes[topic_idx].imshow(wordcloud, interpolation='bilinear')
    axes[topic_idx].set_title(f'Topic {topic_idx + 1}', fontsize=14)
    axes[topic_idx].axis('off')

plt.tight_layout()
plt.savefig('wordclouds.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# PyLDAvis - Visualisasi interaktif (Gensim)
pyLDAvis.enable_notebook()
vis = gensimvis.prepare(gensim_lda, corpus, dictionary, sort_topics=False)
pyLDAvis.display(vis)

# %% [markdown]
# ## 6. Save Model dan Artifacts

# %%
# Save semua model dan preprocessor
import joblib

# Save sklearn LDA model
joblib.dump(lda_model, 'lda_model.pkl')
joblib.dump(vectorizer, 'vectorizer.pkl')
joblib.dump(preprocessor, 'preprocessor.pkl')

# Save Gensim model
gensim_lda.save('gensim_lda_model')
dictionary.save('dictionary.pkl')

# Save topics dictionary
with open('topics.pkl', 'wb') as f:
    pickle.dump(topics_dict, f)

# Save processed data
df.to_csv('processed_data.csv', index=False)

print("\nModel dan artifacts berhasil disimpan!")
print("Files:")
print("- lda_model.pkl")
print("- vectorizer.pkl")
print("- preprocessor.pkl")
print("- gensim_lda_model")
print("- dictionary.pkl")
print("- topics.pkl")
print("- processed_data.csv")

# %%
# Download files untuk deploy ke Streamlit
from google.colab import files

files.download('lda_model.pkl')
files.download('vectorizer.pkl')
files.download('preprocessor.pkl')
files.download('topics.pkl')
files.download('processed_data.csv')
files.download('topic_distribution.png')
files.download('wordclouds.png')

# %% [markdown]
# ## 7. Test Prediction pada Teks Baru

# %%
def predict_topic(text, preprocessor, vectorizer, model, n_words=5):
    """Prediksi topik untuk teks baru"""
    # Preprocess
    cleaned = preprocessor.preprocess(text)

    # Transform
    vectorized = vectorizer.transform([cleaned])

    # Predict
    topic_dist = model.transform(vectorized)[0]
    dominant_topic = topic_dist.argmax()

    # Get top words
    feature_names = vectorizer.get_feature_names_out()
    topic = model.components_[dominant_topic]
    top_indices = topic.argsort()[-n_words:][::-1]
    top_words = [feature_names[i] for i in top_indices]

    return {
        'dominant_topic': int(dominant_topic + 1),
        'topic_distribution': topic_dist.tolist(),
        'top_words': top_words,
        'confidence': float(topic_dist[dominant_topic])
    }

# Test
test_text = "Python is great for building machine learning models and data analysis."
result = predict_topic(test_text, preprocessor, vectorizer, lda_model)

print(f"\nTest Text: {test_text}")
print(f"\nPredicted Topic: Topic {result['dominant_topic']}")
print(f"Confidence: {result['confidence']:.2%}")
print(f"Top Words: {', '.join(result['top_words'])}")
print(f"\nTopic Distribution:")
for i, prob in enumerate(result['topic_distribution']):
    print(f"  Topic {i+1}: {prob:.2%}")

# %%
import os
import re
import pickle
import joblib
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Pastikan resource NLTK tersedia
try:
    ID_STOPWORDS = set(stopwords.words('indonesian'))
except LookupError:
    nltk.download('stopwords', quiet=True)
    ID_STOPWORDS = set(stopwords.words('indonesian'))
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt', quiet=True)

# Stopwords kustom domain
CUSTOM_STOPWORDS = {"itb", "bandung", "itbacid", "dan", "yang"}

class TextPreprocessor:
    def __init__(self, base_stopwords=None, custom_stopwords=None):
        base = set(base_stopwords or ID_STOPWORDS)
        custom = set(custom_stopwords or set())
        self.stop_words = base | custom

    def clean_text(self, text: str) -> str:
        text = str(text).lower()
        text = re.sub(r'https?://\S+|www\.\S+', ' ', text)
        text = re.sub(r'\bitb\.ac\.id\b', ' itb ', text)
        text = re.sub(r'\bnan\b', ' ', text)
        text = re.sub(r'[^a-z0-9\s]', ' ', text)
        text = re.sub(r'\s+', ' ', text).strip()
        return text

    def tokenize(self, text: str):
        tokens = word_tokenize(text)
        tokens = [w for w in tokens if w not in self.stop_words and len(w) > 2]
        return tokens

    def preprocess(self, text: str) -> str:
        cleaned = self.clean_text(text)
        tokens = self.tokenize(cleaned)
        return ' '.join(tokens)

preprocessor = TextPreprocessor(custom_stopwords=CUSTOM_STOPWORDS)

# %%
import os
import pandas as pd

# Muat korpus dari beberapa kandidat lokasi

def load_corpus():
    candidates = [
        "processed_data.csv",
        os.path.join("ITB Official News Dataset (Berita Resmi ITB)", "itb_news.csv")
    ]
    for p in candidates:
        if os.path.exists(p):
            try:
                df = pd.read_csv(p)
                return p, df
            except Exception as e:
                print(f"Gagal membaca {p}: {e}")
    return None, None

path, df = load_corpus()
if path is None or df is None:
    raise FileNotFoundError("Tidak menemukan processed_data.csv atau dataset ITB (itb_news.csv).")

# Tentukan kolom teks
text_col = None
for c in ["text", "content", "body", "article", "cleaned_text"]:
    if c in df.columns:
        text_col = c
        break

if text_col is None:
    raise ValueError(f"Tidak menemukan kolom teks dalam {path}. Kolom tersedia: {df.columns.tolist()}")

# Buat kolom cleaned_text menggunakan preprocessor baru
if text_col != "cleaned_text":
    df["cleaned_text"] = df[text_col].astype(str).map(preprocessor.preprocess)
else:
    # Tetap bersihkan agar konsisten dengan normalisasi baru
    df["cleaned_text"] = df["cleaned_text"].astype(str).map(preprocessor.clean_text)

# Filter dokumen kosong
df = df[df["cleaned_text"].str.len() > 0].copy()

print("Sampel teks:", df["cleaned_text"].head(3).tolist())
print("Jumlah dokumen:", len(df))
# Out:
# Sampel teks: ['ilustrasi gajah dok kementerian pariwisata riau taman nasional tesso nilo tntn kabupaten pelalawan riau salah lanskap hutan terpenting pulau sumatra habitat utama gajah sumatra beserta fauna langka harimau sumatra beruang madu macan dahan tapir cipan kawasan menghadapi tekanan akibat perubahan habitat bertahun melibatkan aspek ekologis sosial pakar ekologi ketua kelompok keilmuan ekologi sekolah ilmu teknologi hayati institut teknologi sith prof tati suryati syamsudin dea', 'deny willy junaidy kiri memasang igw membran ultrafiltrasi teknologi filtrasi air minum berbasis membran memisahkan zat besi fe3 koloid mikroba partikulat alat layanan air bersih keliling dapur dapur daerah terdampak longsor melanda wilayah aceh sumatera barat sumatera utara institut teknologi ikatan alumni rumah amal salman mengerahkan bantuan cepat warga terdampak banjir bandang longsor melanda wilayah aceh sumatera barat sumatera utara berkolaborasi pengda aceh sumatera barat sumatera utara gera
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Vectorizer dengan stopwords Indonesia + kustom
vectorizer = CountVectorizer(
    stop_words=list(preprocessor.stop_words),
    max_df=0.6,
    min_df=2
)

doc_term = vectorizer.fit_transform(df["cleaned_text"])

# Latih LDA
n_topics = 3
lda = LatentDirichletAllocation(
    n_components=n_topics,
    learning_method="batch",
    random_state=42
)
lda.fit(doc_term)

print("Ukuran kosa kata:", len(vectorizer.get_feature_names_out()))
print("Jumlah topik terlatih:", lda.n_components)
# Out:
# c:\Users\szal\Documents\rifa\rifa\nlp\uas\.venv\Lib\site-packages\sklearn\feature_extraction\text.py:411: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['baiknya', 'berkali', 'kali', 'kurangnya', 'mata', 'olah', 'sekurang', 'setidak', 'tama', 'tidaknya'] not in stop_words.
#   warnings.warn(
# Ukuran kosa kata: 6677
# Jumlah topik terlatih: 3

# %%
import numpy as np

TOPIC_BLACKLIST = set(CUSTOM_STOPWORDS)


def get_top_words(model, feature_names, topic_idx, n_top=10, blacklist=None):
    blacklist = blacklist or set()
    comp = model.components_[topic_idx]
    order = np.argsort(comp)[::-1]
    words = []
    for i in order:
        w = feature_names[i]
        if w in blacklist:
            continue
        words.append(w)
        if len(words) >= n_top:
            break
    return words

feature_names = vectorizer.get_feature_names_out()
topics_dict = {}
for k in range(n_topics):
    topics_dict[f"Topik {k+1}"] = get_top_words(lda, feature_names, k, 10, TOPIC_BLACKLIST)

for k, v in topics_dict.items():
    print(k, ":", ", ".join(v))
# Out:
# Topik 1 : institut, indonesia, teknik, salah, prof, ilmu, 2024, industri, fakultas, kuliah
# Topik 2 : mahasiswa, teknik, indonesia, institut, tim, juara, diselenggarakan, berhasil, meraih, universitas
# Topik 3 : institut, mahasiswa, kampus, 2025, kegiatan, program, 2024, acara, ganesha, masyarakat

# %%
# Simpan artefak untuk aplikasi Streamlit
joblib.dump(lda, "lda_model.pkl")
joblib.dump(vectorizer, "vectorizer.pkl")
joblib.dump(preprocessor, "preprocessor.pkl")
with open("topics.pkl", "wb") as f:
    pickle.dump(topics_dict, f)

print("Disimpan: lda_model.pkl, vectorizer.pkl, preprocessor.pkl, topics.pkl")
# Out:
# Disimpan: lda_model.pkl, vectorizer.pkl, preprocessor.pkl, topics.pkl
